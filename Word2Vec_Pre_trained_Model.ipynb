# %% [markdown]
# <a href="https://colab.research.google.com/github/BDH-teacher/Deep_Learning_Audit_code/blob/main/Word2Vec_Pre_trained_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 71.3 MB/s eta 0:00:00
# ...

# %%
# To leverage a pre-trained word2vec model, please refer the following code
#https://radimrehurek.com/gensim/models/word2vec.html
import gensim.downloader as api
from gensim.models import KeyedVectors

model = api.load('glove-wiki-gigaword-100')
print(model)
### Possible models in gensim library
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# KeyedVectors<vector_size=100, 400000 keys>

# %%
print(model['good'])
print(model['good'].shape)
# Out:
# [-0.030769   0.11993    0.53909   -0.43696   -0.73937   -0.15345
#   0.081126  -0.38559   -0.68797   -0.41632   -0.13183   -0.24922
#   0.441      0.085919   0.20871   -0.063582   0.062228  -0.051234
#  -0.13398    1.1418     0.036526   0.49029   -0.24567   -0.412
#   0.12349    0.41336   -0.48397   -0.54243   -0.27787   -0.26015
#  -0.38485    0.78656    0.1023    -0.20712    0.40751    0.32026
#  -0.51052    0.48362   -0.0099498 -0.38685    0.034975  -0.167
#   0.4237    -0.54164   -0.30323   -0.36983    0.082836  -0.52538
#  -0.064531  -1.398     -0.14873   -0.35327   -0.1118     1.0912
#   0.095864  -2.8129     0.45238    0.46213    1.6012    -0.20837
#  -0.27377    0.71197   -1.0754    -0.046974   0.67479   -0.065839
#   0.75824    0.39405    0.15507   -0.64719    0.32796   -0.031748
#   0.52899   -0.43886    0.67405    0.42136   -0.11981   -0.21777
#  -0.29756   -0.1351     0.59898    0.46529   -0.58258   -0.02323
# ...

# %%
model.most_similar('bad')
# Out:
# [('worse', 0.7929712533950806),
#  ('good', 0.7702797651290894),
#  ('things', 0.7653602957725525),
#  ('too', 0.7630148530006409),
#  ('thing', 0.7609668374061584),
#  ('lot', 0.7443646788597107),
#  ('kind', 0.7408681511878967),
#  ('because', 0.7398799061775208),
#  ('really', 0.7376540899276733),
#  ("n't", 0.7336540818214417)]

# %%
model.most_similar('korea')
# Out:
# [('pyongyang', 0.8227901458740234),
#  ('korean', 0.806920051574707),
#  ('dprk', 0.7862391471862793),
#  ('seoul', 0.7670401930809021),
#  ('japan', 0.76695317029953),
#  ('china', 0.746388852596283),
#  ('south', 0.7456807494163513),
#  ('koreans', 0.7317502498626709),
#  ('north', 0.7094979286193848),
#  ('iran', 0.6951658129692078)]

# %%
model.most_similar('south korea')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1011389694.py in <cell line: 0>()
# ----> 1 model.most_similar('south korea')
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     841
#     842         # compute the weighted average of all keys
# --> 843         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     844         all_keys = [
#     845             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516                 total_weight += abs(weights[idx])
# ...

# %%
from copy import deepcopy
wv = deepcopy(model['south'])
# print(wv)
wv += deepcopy(model['korea'])
wv /= 2
# print(model['korea'])
# print(wv)
print(model.most_similar(positive=wv))
print(model.most_similar('seoul'))
# Out:
# [('korea', 0.9385793805122375), ('south', 0.9297975301742554), ('north', 0.8691936135292053), ('korean', 0.7910293936729431), ('seoul', 0.7571862936019897), ('pyongyang', 0.7377851605415344), ('east', 0.7189022302627563), ('china', 0.7181861400604248), ('west', 0.7169296145439148), ('koreans', 0.7128651142120361)]
# [('pyongyang', 0.7844952344894409), ('beijing', 0.7833213806152344), ('korea', 0.7670402526855469), ('tokyo', 0.7606267929077148), ('korean', 0.7107508182525635), ('taipei', 0.7077510952949524), ('hanoi', 0.6704674959182739), ('south', 0.6439112424850464), ('tehran', 0.6375713348388672), ('busan', 0.6357340812683105)]

# %%
model.most_similar(positive=['king','woman'],negative=['man'])
# Out:
# [('queen', 0.7698540687561035),
#  ('monarch', 0.6843381524085999),
#  ('throne', 0.6755736470222473),
#  ('daughter', 0.6594556570053101),
#  ('princess', 0.6520534157752991),
#  ('prince', 0.6517034769058228),
#  ('elizabeth', 0.6464517712593079),
#  ('mother', 0.631171703338623),
#  ('emperor', 0.6106470823287964),
#  ('wife', 0.6098655462265015)]

# %%
model.most_similar(positive=["🍔"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-791851979.py in <cell line: 0>()
# ----> 1 model.most_similar(positive=["🍔"])
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     841
#     842         # compute the weighted average of all keys
# --> 843         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     844         all_keys = [
#     845             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516                 total_weight += abs(weights[idx])
# ...

# %%
model.most_similar(negative='good')
# Out:
# [('atentamente', 0.6840597987174988),
#  ('brett.clanton@chron.com', 0.6830008029937744),
#  ('+10.00', 0.6809892058372498),
#  ('ryryryryryry', 0.6789417862892151),
#  ('ngabo', 0.6737895607948303),
#  ('juta', 0.6687334179878235),
#  ('purva.patel@chron.com', 0.6658638715744019),
#  ('methoni', 0.6640544533729553),
#  ('kilakarai', 0.6625359654426575),
#  ('jenalia.moreno@chron.com', 0.6624385118484497)]

# %%
model.most_similar(positive=['paris','germany'], negative=['berlin'], topn = 1)
# Out:
# [('france', 0.8984005451202393)]
