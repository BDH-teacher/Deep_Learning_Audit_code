# %% [markdown]
# <a href="https://colab.research.google.com/github/BDH-teacher/Deep_Learning_Audit_code/blob/main/Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy.random import randn

np.random.seed(0)

# n: #examples, d: input dim, h: hidden dim, c: #classes
n, d, h, c = 64, 1000, 100, 10
x, y = randn(n, d), randn(n, c)
w1, w2 = randn(d, h), randn(h, c)
learning_rate = 1e-4

# %%
for t in range(1000):
    y_0 = x.dot(w1)
    h = 1 / (1 + np.exp(-y_0))
    y_pred = h.dot(w2)
    loss = np.square(y_pred - y).sum()
    print(t, loss)

    grad_y_pred = 2.0 * (y_pred - y)
    grad_w2 = h.T.dot(grad_y_pred)
    grad_h = grad_y_pred.dot(w2.T)
    grad_w1 = x.T.dot(grad_h * h * (1 - h))

    w1 -= learning_rate * grad_w1
    w2 -= learning_rate * grad_w2
# Out:
# 0 24635.893498628233
# 1 17744.75214146344
# 2 14607.620034029624
# 3 12903.09828800124
# 4 11843.335741335539
# 5 11120.497207975923
# 6 10541.712097289867
# 7 10023.406934059098
# 8 9595.725550903948
# 9 9234.50926833751
# 10 8926.01022369324
# 11 8653.28705111339
# 12 8395.589149585961
# 13 8143.607961683161
# 14 7923.7605478056585
# 15 7734.605117428746
# 16 7561.286097257185
# 17 7395.3025791891505
# 18 7238.516906122122
# 19 7089.507953261254
# 20 6943.595137976303
# 21 6798.032222843932
# 22 6657.828125060358
# 23 6523.6068291136635
# 24 6402.811442317958
# 25 6293.539165479022
# 26 6189.54372468327
# 27 6088.025659798785
# 28 5987.802513351187
# 29 5887.785636878435
# 30 5786.308168514858
# 31 5682.000258424603
# 32 5574.832753012499
# 33 5472.978208479717
# 34 5381.410603648272
# 35 5295.690114933057
# 36 5214.145332390912
# 37 5135.7044541425485
# 38 5059.110865234788
# 39 4983.615143151119
# 40 4909.123274402547
# 41 4836.152360431746
# 42 4765.467287299275
# ...
